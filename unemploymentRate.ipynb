# %%
import pandas as pd

# %%
employmentData = pd.read_csv("employmentData (complete)/employmentData.csv")

# %%
employmentData
# Out:
#        date Industrial aggregate including unclassified businesses 6 7  \
# 0    Jan-10                                         14,303,330
# 1    Feb-10                                         14,351,994
# 2    Mar-10                                         14,402,242
# 3    Apr-10                                         14,540,918
# 4    May-10                                         14,774,410
# 5    Jun-10                                         15,036,935
# 6    Jul-10                                         14,852,036
# 7    Aug-10                                         14,630,995
# 8    Sep-10                                         14,958,547
# 9    Oct-10                                         15,002,276
# 10   Nov-10                                         14,945,157
# 11   Dec-10                                         15,064,273
# 12   Jan-11                                         14,566,758
# 13   Feb-11                                         14,620,012
# ...

# %%
employmentData = pd.read_csv("")
